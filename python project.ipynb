# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


game = pd.read_csv('vgsales.csv', index_col=False)
game
# Out:
#       Rank                                               Name Platform  \
# 0        1                                         Wii Sports      Wii
# 1        2                                  Super Mario Bros.      NES
# 2        3                                     Mario Kart Wii      Wii
# 3        4                                  Wii Sports Resort      Wii
# 4        5                           Pokemon Red/Pokemon Blue       GB
# ...    ...                                                ...      ...
# 9843  9845                                       Burning Road       PS
# 9844  9846                                            Slayers     SNES
# 9845  9847  Super Robot Wars OG Saga: Masou Kishin - The L...       DS
# 9846  9848                                     IndyCar Series      PS2
# 9847  9849                                       Space Chimps      PS2
#
#         Year         Genre            Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9848 entries, 0 to 9847
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          9848 non-null   int64
#  1   Name          9848 non-null   object
#  2   Platform      9848 non-null   object
#  3   Year          9691 non-null   float64
#  4   Genre         9848 non-null   object
#  5   Publisher     9818 non-null   object
#  6   NA_Sales      9848 non-null   float64
#  7   EU_Sales      9848 non-null   float64
#  8   JP_Sales      9848 non-null   float64
#  9   Other_Sales   9848 non-null   float64
#  10  Global_Sales  9848 non-null   float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 846.4+ KB

# %%
game['Year'].fillna(game['Year'].mode()[0], inplace=True)
game['Publisher'].fillna(game['Publisher'].mode()[0], inplace=True)

# %%
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9848 entries, 0 to 9847
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          9848 non-null   int64
#  1   Name          9848 non-null   object
#  2   Platform      9848 non-null   object
#  3   Year          9848 non-null   float64
#  4   Genre         9848 non-null   object
#  5   Publisher     9848 non-null   object
#  6   NA_Sales      9848 non-null   float64
#  7   EU_Sales      9848 non-null   float64
#  8   JP_Sales      9848 non-null   float64
#  9   Other_Sales   9848 non-null   float64
#  10  Global_Sales  9848 non-null   float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 846.4+ KB

# %%
game.describe()
# Out:
#               Rank         Year     NA_Sales     EU_Sales     JP_Sales  \
# count  9848.000000  9848.000000  9848.000000  9848.000000  9848.000000
# mean   4925.433692  2005.716795     0.429949     0.239972     0.120091
# std    2843.124307     6.148654     1.027816     0.639414     0.395362
# min       1.000000  1980.000000     0.000000     0.000000     0.000000
# 25%    2463.750000  2002.000000     0.100000     0.020000     0.000000
# 50%    4925.500000  2007.000000     0.190000     0.080000     0.000000
# 75%    7387.250000  2010.000000     0.430000     0.220000     0.080000
# max    9849.000000  2020.000000    41.490000    29.020000    10.220000
#
#        Other_Sales  Global_Sales
# count  9848.000000   9848.000000
# mean      0.079102      0.869113
# std       0.239915      1.950505
# min       0.000000      0.120000
# 25%       0.010000      0.210000
# 50%       0.030000      0.390000
# 75%       0.070000      0.840000
# max      10.570000     82.740000

# %%
game.index
# Out:
# RangeIndex(start=0, stop=9848, step=1)

# %%
game.index.values
# Out:
# array([   0,    1,    2, ..., 9845, 9846, 9847], dtype=int64)

# %%
game_sort=game.sort_values('Global_Sales', ascending=False)
game_sort
# Out:
#       Rank                                     Name Platform    Year  \
# 0        1                               Wii Sports      Wii  2006.0
# 1        2                        Super Mario Bros.      NES  1985.0
# 2        3                           Mario Kart Wii      Wii  2008.0
# 3        4                        Wii Sports Resort      Wii  2009.0
# 4        5                 Pokemon Red/Pokemon Blue       GB  1996.0
# ...    ...                                      ...      ...     ...
# 9723  9725  Puzzle Quest: Challenge of the Warlords      PS2  2007.0
# 9724  9726                    Angry Birds Star Wars      PSV  2013.0
# 9725  9727                       Guardian's Crusade       PS  1998.0
# 9726  9728                           Undead Knights      PSP  2009.0
# 9847  9849                             Space Chimps      PS2  2008.0
#
#              Genre            Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
game_sort.head(20)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
sns.set_color_codes("pastel")
sns.barplot(x="Global_Sales", y="Name", data=game_top,
            label="Global_Sales", color="b")
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Name'>

# %% [markdown]
# group = game.groupby("Publisher")
# list(group)

# %%
game_Microsoft=group.get_group('Microsoft Game Studios')
game_Microsoft
# Out:
#       Rank                     Name Platform    Year     Genre  \
# 15      16       Kinect Adventures!     X360  2010.0      Misc
# 43      44                   Halo 3     X360  2007.0   Shooter
# 62      63              Halo: Reach     X360  2010.0   Shooter
# 65      66                   Halo 4     X360  2012.0   Shooter
# 72      73                Minecraft     X360  2013.0      Misc
# ...    ...                      ...      ...     ...       ...
# 8994  8996  Grabbed by the Ghoulies       XB  2003.0    Action
# 9183  9185     Lips: I Love The 80s     X360  2010.0      Misc
# 9498  9500              NightCaster       XB  2002.0    Action
# 9643  9645         Quantum Redshift       XB  2002.0    Racing
# 9758  9760             Voodoo Vince       XB  2003.0  Platform
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 15    Microsoft Game Studios     14.97      4.94      0.24         1.67
# ...

# %%
game_Nintendo=game[game['Publisher'].isin(['Nintendo'])]
game_Nintendo
# Out:
#       Rank                                               Name Platform  \
# 0        1                                         Wii Sports      Wii
# 1        2                                  Super Mario Bros.      NES
# 2        3                                     Mario Kart Wii      Wii
# 3        4                                  Wii Sports Resort      Wii
# 4        5                           Pokemon Red/Pokemon Blue       GB
# ...    ...                                                ...      ...
# 9301  9303                            Kororinpa: Marble Mania      Wii
# 9461  9463                                   Illusion of Gaia     SNES
# 9479  9481                                 Sin and Punishment      N64
# 9567  9569  Pokémon: For Ho-Oh the Bells Toll!: Game Boy A...      GBA
# 9736  9738                      Eyeshield 21: Max Devil Power       DS
#
#         Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
genre_mean = game.groupby(by='Genre')['Global_Sales'].mean().sort_values(ascending=False)
genre_mean
# Out:
# Genre
# Platform        1.327964
# Shooter         1.191755
# Role-Playing    0.986211
# Racing          0.905372
# Puzzle          0.846162
# Action          0.806343
# Sports          0.798424
# Fighting        0.788938
# Misc            0.769609
# Simulation      0.767670
# Strategy        0.522977
# Adventure       0.508413
# Name: Global_Sales, dtype: float64

# %%
genre_mean.plot.bar()
# Out:
# <AxesSubplot:xlabel='Genre'>

# %%
genre_sum = game.groupby(by='Genre')['Global_Sales'].sum().sort_values(ascending=False)
genre_sum
# Out:
# Genre
# Action          1684.45
# Sports          1287.06
# Shooter         1011.80
# Role-Playing     895.48
# Platform         815.37
# Misc             768.07
# Racing           706.19
# Fighting         430.76
# Simulation       372.32
# Puzzle           229.31
# Adventure        201.84
# Strategy         156.37
# Name: Global_Sales, dtype: float64

# %%
genre_sum.plot.bar()
# Out:
# <AxesSubplot:xlabel='Genre'>

# %%
publisher_sum = game.groupby(by='Publisher')['Global_Sales'].sum().sort_values(ascending=False)
publisher_sum
# Out:
# Publisher
# Nintendo                       1781.08
# Electronic Arts                1110.67
# Activision                      711.86
# Sony Computer Entertainment     598.17
# Ubisoft                         455.97
#                                 ...
# SCS Software                      0.13
# Telstar                           0.13
# FunSoft                           0.12
# MTO                               0.12
# DHM Interactive                   0.12
# Name: Global_Sales, Length: 334, dtype: float64

# %%
publisher_sum.head(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='Publisher'>

# %%
publisher_mean = game.groupby(by='Publisher')['Global_Sales'].mean().sort_values(ascending=False)
publisher_mean
# Out:
# Publisher
# Palcom                4.170000
# Nintendo              2.877351
# RedOctane             2.870000
# Red Orb               2.620000
# JVC                   2.400000
#                         ...
# Havas Interactive     0.130000
# Bigben Interactive    0.125000
# MTO                   0.120000
# FunSoft               0.120000
# DHM Interactive       0.120000
# Name: Global_Sales, Length: 334, dtype: float64

# %%
publisher_mean.head(10).plot.bar()
# Out:
# <AxesSubplot:xlabel='Publisher'>
